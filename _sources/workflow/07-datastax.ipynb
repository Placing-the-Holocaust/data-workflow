# %%
import glob
import pandas as pd
from tqdm import tqdm
import numpy as np
from astrapy import DataAPIClient
import os
from dotenv import load_dotenv
# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
# Get API key and URL from environment variables
ASTRA_TOKEN = os.getenv('ASTRA_TOKEN')
ASTRA_API_ENDPOINT = os.getenv('ASTRA_API_ENDPOINT')

# %%
# connect to a database
client = DataAPIClient(ASTRA_TOKEN)

# %%
database = client.get_database(ASTRA_API_ENDPOINT)

# %%
print(f"ASTRA_TOKEN: {ASTRA_TOKEN}")
print(f"ASTRA_API_ENDPOINT: {ASTRA_API_ENDPOINT}")
# Out:
# ASTRA_TOKEN: AstraCS:EtDeDieMsPARStKtcnZOFOdY:3f802e2e07da5be014ce2a3d26dcc8693c8acde7dd35dbe1df384624f83397d3
# ASTRA_API_ENDPOINT: https://2534174f-90b3-4e11-afb5-8ee29c3c090d-us-east-2.apps.astra.datastax.com

# %%
print(f"Connected to Astra DB: {database.list_collection_names()}")
# Out:
# Connected to Astra DB: []

# %%
collection_name = "HolocaustTestimonies"


# Create or get the collection
collection = database.create_collection(collection_name, dimension=768)

# Define the schema
schema = {
    "sentence_ids": "list<text>",
    "text": "text",
    "category": "text",
    "populated_place": "int",
    "building": "int",
    "country": "int",
    "spatial_obj": "int",
    "dlf": "int",
    "int_space": "int",
    "env_features": "int",
    "region": "int",
    "npip": "int",
    "experience_group": "text",
    "birth_country": "text",
    "gender": "text",
    "rg": "text",
    "full_name": "text",
    "birth_year": "int"
}

print(f"Collection '{collection_name}' created successfully.")
# Out:
# Collection 'HolocaustTestimonies' created successfully.

# %%
# Get list of parquet files
parquet_files = glob.glob("../data/06_parquet/*.parquet")
parquet_files.sort()
parquet_files = parquet_files
print(f"Found {len(parquet_files)} parquet files.")

# Function to prepare a single row
def prepare_row(row):
    def safe_int(value):
        return int(value) if value is not None else 0

    return {
        "sentence_ids": row['sentence_ids'].tolist() if isinstance(row['sentence_ids'], np.ndarray) else row['sentence_ids'],
        "text": row['text'],
        "category": row['category'],
        "populated_place": safe_int(row['populated_place']),
        "building": safe_int(row['building']),
        "country": safe_int(row['country']),
        "spatial_obj": safe_int(row['spatial_obj']),
        "dlf": safe_int(row['dlf']),
        "int_space": safe_int(row['int_space']),
        "env_features": safe_int(row['env_features']),
        "region": safe_int(row['region']),
        "npip": safe_int(row['npip']),
        "experience_group": row['experience_group'],
        "birth_country": row['birth_country'],
        "gender": row['gender'],
        "rg": row['rg'],
        "full_name": row['full_name'],
        "birth_year": safe_int(row['birth_year']),
        "$vector": row['embedding'].tolist() if isinstance(row['embedding'], np.ndarray) else row['embedding']
    }

# Process each parquet file
for parquet_file in parquet_files:
    df = pd.read_parquet(parquet_file)
    
    data_rows = []
    for _, row in tqdm(df.iterrows(), total=len(df), desc="Preparing data"):
        data_rows.append(prepare_row(row))
    
    # Perform batch insertion
    for i in tqdm(range(0, len(data_rows), 100), desc="Inserting data"):
        batch = data_rows[i:i+100]
        collection.insert_many(documents=batch)

print("Data insertion complete.")
# Out:
# Found 979 parquet files.
# Preparing data: 100%|██████████| 1050/1050 [00:00<00:00, 24536.70it/s]
# Inserting data: 100%|██████████| 11/11 [00:02<00:00,
/s]
# Inserting data: 100%|██████████| 13/13 [00:03<00:00,  4.12it/s]
# Preparing data: 100%|██████████| 497/497 [00:00<00:00, 18482.02it/s]
# Inserting data: 100%|██████████| 5/5 [00:01<00:00,  4.11it/s]
# Preparing data: 100%|██████████| 2453/2453 [00:00<00:00, 22689.66it/s]
# Inserting data: 100%|██████████| 25/25 [00:06<00:00,  3.92it/s]
# Preparing data: 100%|██████████| 2474/2474 [00:00<00:00, 24231.62it/s]
# Inserting data: 100%|██████████| 25/25 [00:06<00:00,  4.07it/s]
# Preparing data: 100%|██████████| 2168/2168 [00:00<00:00, 21463.71it/s]
# Inserting data: 100%|██████████| 22/22 [00:05<00:00,  4.04it/s]
# Preparing data: 100%|██████████| 1201/1201 [00:00<00:00, 20989.87it/s]
# Inserting data: 100%|██████████| 13/13 [00:03<00:00,  3.77it/s]
# Preparing data: 100%|██████████| 1265/1265 [00:00<00:00, 21302.51it/s]
# Inserting data: 100%|██████████| 13/13 [00:04<00:00,  2.63it/s]
# Preparing data: 100%|██████████| 2372/2372 [00:00<00:00, 20938.33it/s]
# Inserting data: 100%|██████████| 24/24 [00:06<00:00,  3.69it/s]
# Preparing data: 100%|██████████| 4376/4376 [00:00<00:00, 22900.91it/s]
# Inserting data: 100%|██████████| 44/44 [00:11<00:00,  3.93it/s]
# Preparing data: 100%|██████████| 3510/3510 [00:00<00:00, 23616.01it/s]
# Inserting data: 100%|██████████| 36/36 [00:08<00:00,  4.18it/s]
# Preparing data: 100%|██████████| 1730/1730 [00:00<00:00, 23086.03it/s]
# Inserting data: 100%|██████████| 18/18 [00:04<00:00,  4.18it/s]
# Preparing data: 100%|██████████| 1135/1135 [00:00<00:00, 16613.28it/s]
# Inserting data: 100%|██████████| 12/12 [00:02<00:00,  4.05it/s]
# Preparing data: 100%|██████████| 1539/1539 [00:00<00:00, 19452.66it/s]
# Inserting data: 100%|██████████| 16/16 [00:04<00:00,  3.91it/s]
# Data insertion complete.

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('sentence-transformers/LaBSE')
# Out:
# /Applications/anaconda3/envs/fasthtml/lib/python3.10/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /Applications/anaconda3/envs/fasthtml/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /Applications/anaconda3/envs/fasthtml/lib/python3.10/site-packages/sentence_transformers/models/Dense.py:89: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(os.path.join(input_path, "pytorch_model.bin"), map_location=torch.device("cpu"))

# %%
# Query the collection with the phrase "Hunger"
query_text = "Wir hatten keine Essen."

# Encode the query text
query_embedding = model.encode(query_text)

# Perform the vector search
search_results = collection.find(
    filter={},
    sort={"$vector": query_embedding},
    limit=5
)

print(f"Top 5 results for the query '{query_text}':")
for i, doc in enumerate(search_results, 1):
    print(f"{i}. Text: {doc['text']}")
    print(f"   Category: {doc['category']}")
    print(f"   Experience Group: {doc['experience_group']}")
    print()
# Out:
# Top 5 results for the query 'Wir hatten keine Essen.':
# 1. Text: We were there.  There was no food.  There was no water.
#    Category: answer
#    Experience Group: survivor
#
# 2. Text: A: We didn't eat.  Nobody ate.
#    Category: answer
#    Experience Group: survivor
#
# 3. Text: No food.  No nothing.  Yah?
#    Category: answer
#    Experience Group: survivor
#
# 4. Text: A: We -- we hardly had food to eat.
#    Category: answer
#    Experience Group: survivor
#
# 5. Text: A: Not much.  We couldn't eat.  We had some food, you know.
#    Category: answer
#    Experience Group: survivor

# %%
doc
# Out:
# {'_id': 'ef2dacf0-f88e-420f-adac-f0f88ee20f4a',
#  'sentence_ids': ['2339', '2340'],
#  'text': "Q: You're tired aren't you.  Do you want to stop? ",
#  'category': 'question',
#  'populated_place': 0,
#  'building': 0,
#  'country': 0,
#  'spatial_obj': 0,
#  'dlf': 0,
#  'int_space': 0,
#  'env_features': 0,
#  'region': 0,
#  'npip': 0,
#  'experience_group': 'survivor',
#  'birth_country': 'poland',
#  'gender': 'm',
#  'rg': 'rg-50.030.0001',
#  'full_name': 'david a. kochalski',
#  'birth_year': 1928}

# %%
# Query the collection with the phrase "Hunger" and additional filters
query_text = "Wir hatten keine essen"

# Encode the query text
query_embedding = model.encode(query_text)

# Perform the vector search with filters
results =collection.find(
    filter={
        "building": {"$gt": 0},
        "birth_country": "poland"
    },
    sort={"$vector": query_embedding},
    limit=200,
    include_similarity=True,
    max_time_ms=300000
)

# %%
for doc in results:
    print(doc)
    print(doc["$similarity"])
    print(f"{i}. Text: {doc['text']}")
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File /Applications/anaconda3/envs/fasthtml/lib/python3.10/site-packages/astrapy/api_commander.py:283, in APICommander.raw_request(self, http_method, payload, additional_path, raise_api_errors, timeout_info)
#     282 try:
# --> 283     raw_response.raise_for_status()
#     284 except httpx.HTTPStatusError as http_exc:
#
# File /Applications/anaconda3/envs/fasthtml/lib/python3.10/site-packages/httpx/_models.py:761, in Response.raise_for_status(self)
#     760 message = message.format(self, error_type=error_type)
# --> 761 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Server error '504 Gateway Timeout' for url 'https://2534174f-90b3-4e11-afb5-8ee29c3c090d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/HolocaustTestimonies'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/504
#
# During handling of the above exception, another exception occurred:
#
# DataAPIHttpException                      Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 for doc in results:
#       2     print(doc)
#       3     print(doc["$similarity"])
#
# File /Applications/anaconda3/envs/fasthtml/lib/python3.10/site-packages/astrapy/cursors.py:634, in Cursor.__next__(self)
#     627         raise DataAPITimeoutException(
#     628             text="Cursor timed out.",
#     629             timeout_type="generic",
#     630             endpoint=None,
#     631             raw_payload=None,
#     632         )
#     633 try:
# --> 634     next_item = self._iterator.__next__()
#     635     self._retrieved = self._retrieved + 1
#     636     return next_item
#
# File /Applications/anaconda3/envs/fasthtml/lib/python3.10/site-packages/astrapy/cursors.py:183, in _LookAheadIterator.__next__(self)
#     181     return self.preread_item  # type: ignore[return-value]
#     182 else:
# --> 183     return next(self.iterator)
#
# File /Applications/anaconda3/envs/fasthtml/lib/python3.10/site-packages/astrapy/cursors.py:700, in Cursor._create_iterator.<locals>._find_iterator()
#     698 next_page_state: Optional[str] = None
#     699 #
# --> 700 resp_0 = self._collection.command(
#     701     body=f0_payload,
#     702     max_time_ms=self._max_time_ms,
#     703 )
#     704 self._api_response_status = resp_0.get("status")
#     705 if "nextPageState" not in resp_0.get("data", {}):
#
# File /Applications/anaconda3/envs/fasthtml/lib/python3.10/site-packages/astrapy/collection.py:2785, in Collection.command(self, body, raise_api_errors, max_time_ms)
#    2783 _cmd_desc = ",".join(sorted(body.keys()))
#    2784 logger.info(f"command={_cmd_desc} on '{self.name}'")
# -> 2785 command_result = self._api_commander.request(
#    2786     payload=body,
#    2787     raise_api_errors=raise_api_errors,
#    2788     timeout_info=base_timeout_info(_max_time_ms),
#    2789 )
#    2790 logger.info(f"finished command={_cmd_desc} on '{self.name}'")
#    2791 return command_result
#
# File /Applications/anaconda3/envs/fasthtml/lib/python3.10/site-packages/astrapy/api_commander.py:340, in APICommander.request(self, http_method, payload, additional_path, raise_api_errors, timeout_info)
#     331 def request(
#     332     self,
#     333     *,
#    (...)
#     338     timeout_info: TimeoutInfoWideType = None,
#     339 ) -> Dict[str, Any]:
# --> 340     raw_response = self.raw_request(
#     341         http_method=http_method,
#     342         payload=payload,
#     343         additional_path=additional_path,
#     344         raise_api_errors=raise_api_errors,
#     345         timeout_info=timeout_info,
#     346     )
#     347     return self._raw_response_to_json(
#     348         raw_response, raise_api_errors=raise_api_errors, payload=payload
#     349     )
#
# File /Applications/anaconda3/envs/fasthtml/lib/python3.10/site-packages/astrapy/api_commander.py:285, in APICommander.raw_request(self, http_method, payload, additional_path, raise_api_errors, timeout_info)
#     283     raw_response.raise_for_status()
#     284 except httpx.HTTPStatusError as http_exc:
# --> 285     raise self._http_exc_class.from_httpx_error(http_exc)
#     286 log_httpx_response(response=raw_response)
#     287 return raw_response
#
# DataAPIHttpException: Driver timeout: (QueryConsistencyException/ReadTimeoutException) Cassandra timeout during read query at consistency LOCAL_ONE (1 responses were required but only 0 replica responded). In case this was generated during read repair, the consistency level is not representative of the actual consistency.. Server error '504 Gateway Timeout' for url 'https://2534174f-90b3-4e11-afb5-8ee29c3c090d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/HolocaustTestimonies'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/504

# %%
batch_size = 50  # Adjust this value based on your needs

while True:
    cursor = collection.find(
        filter={
            "building": {"$gt": 0},
            "birth_country": "poland"
        },
        sort={"$vector": query_embedding},
        limit=batch_size,
        include_similarity=True,
        max_time_ms=60000  # 1 minute per batch
    )

    try:
        batch_count = 0
        for doc in cursor:
            print(f"Text: {doc['text']}")
            print(f"Similarity: {doc['$similarity']}")
            print()
            batch_count += 1

        if batch_count < batch_size:
            # We've retrieved fewer documents than the batch size,
            # which likely means we've reached the end of the results
            break
    except Exception as e:
        print(f"An error occurred: {e}")
        break
# Out:
# Text: A: We had -- we never saw food.  We never saw food.  It was just a bookkeeping department.
# Similarity: 0.79009813
#
# Text: A: Well, we never owned the house.  We always --
# Similarity: 0.7870524
#
# Text: A: There was no home.
# Similarity: 0.78013104
#
# Text: Q: There was no home.
# Similarity: 0.7771603
#
# Text: A: There wasn't any exchange.
# Similarity: 0.77669203
#
# Text: A: They didn't give us any food.  The food was from the house, whatever you could get.
# Similarity: 0.772472
#
# Text: When the Germans came in, my father...1 mean actually we were...we had no food in the house.  It was not like here.  You had always something in the house.
# Similarity: 0.76997393
#
# Text: We never saw food.  It was just a bookkeeping department.  I never -- no food went through -- we were a part of the so-called Aprovisation Department.
# Similarity: 0.76886326
#
# Text: A: Okay.  When the Germans came in, my father...1 mean actually we were...we had no food in the house.  It was not like here.
# Similarity: 0.76572216
#
# Text: The room what we had - no kitchen, no water.  I made lights for myself.  No electricity was over there - in the house.
# Similarity: 0.7646773
#
# Text: A: -- the house was torn apart.  There was -- there was nothing that we didn't -- Mother didn't have a pot to -- to cook in.
# Similarity: 0.7619529
#
# Text: A: And went to s -- no, we didn't go to school.
# Similarity: 0.76149726
#
# Text: Q: There was no store.
# Similarity: 0.76128656
#
# Text: A: It's not a -- that's not -- we don't have an apartment buildings.
# Similarity: 0.7591801
#
# Text: I don't...didn't have much of any other money, we passed a bakery and we bought bread.  But we were so hungry that when we walked to...from the place of work...from the bakery to the house when we came to the house we did not...both have anymore bread.  We had to wait for another 24 hours until we will earn the money and get another bread.
# Similarity: 0.7583846
#
# Text: A: -- and we had some food.  But otherwise, there was no shops to buy any food.  They -- not even for the communists who were there, they probably had something --
# Similarity: 0.7581223
#
# Text: The first night no food I got.  I didn't go to some...to... to houses to ask for eat or what.  And I came in the forest and the first night...that's...that's mean the second night, first night I was...when I left from the...from the barn.
# Similarity: 0.7573924
#
# Text: A: -- no place where to stay, and they -- and there was no kitchen for them to feed them, or publ - - you know, public place where to sleep --
# Similarity: 0.75588036
#
# Text: A: We had -- we had a store.
# Similarity: 0.7557608
#
# Text: A: We had three shuls.
# Similarity: 0.7555997
#
# Text: And...uh...wherever I...we were earning for that day...working a day...we were paid by the day...it's sad, at the end of the day, we were paid and...uh...after getting the money.  I don't...didn't have much of any other money, we passed a bakery and we bought bread.  But we were so hungry that when we walked to...from the place of work...from the bakery to the house when we came to the house we did not...both have anymore bread.
# Similarity: 0.75454855
#
# Text: A: No we did it at home.  I don't remember if there was a shower.  No there was no bathroom.
# Similarity: 0.7544693
#
# Text: We had no food, nothing.  So we tried to get back home, which what belonged to the German side.  At that time, the Russians took us.
# Similarity: 0.7540114
#
# Text: A: No, you -- no, we never [indecipherable] no, we didn't have this with us, no, we didn't have this.  We expected the 10 men, they going to have a place, a home for us.  See, we didn't meet them for -- took us a -- took us a long time.
# Similarity: 0.7533417
#
# Text: I didn't have bread.  Nothing!  They used to sit down just like home.
# Similarity: 0.75314987
#
# Text: A: No.  They didn't give us any food.  We went into the shop and then we start, you know, still crying and talking to each other.
# Similarity: 0.7531284
#
# Text: And we had already -- they helped us.  There was no problem with food and housing and all that.  Andso. . .
# Similarity: 0.75209236
#
# Text: We didn't know where to go.  And we went into the houses.  Of course, the dinner was...no dinner, you could imagine.
# Similarity: 0.7520621
#
# Text: A: Gymnasium, no.  No.  I had, I didn't have public school either because we had our own school.
# Similarity: 0.7520269
#
# Text: A: And we didn't talk about our experiences at all.  It was the school and what -- how to do it.  And under the -- under our school, there were food magazines.
# Similarity: 0.7517779
#
# Text: A: No, sometimes when you went in.  We didn't have toilets we went out not even an outhouse, under there someplace where ever we found a place.  We didn't have anything.
# Similarity: 0.7516415
#
# Text: We didn't have carpet.  And we didn't have...We needed everything.  You could have gone to whatever shop you wanted. (
# Similarity: 0.7513429
#
# Text: A: We couldn't stay in Poland, no.  We left our house and everything.  We went to Czechoslovakia.
# Similarity: 0.7499917
#
# Text: Nothing.  We sit in these barracks.  No food.
# Similarity: 0.7495064
#
# Text: A: You know ac -- you know, ya -- this you get sa -- no, it wasn't a question that I a -- I had to work because if I didn't work then there was no ration card, there was no food.  Whatever little food we had, I had to obtain on my ration card.  At work we worked like six days a week from what, I don't know, seven to seven or something, and there was nightshifts as well, which I didn't work and lunch time we used to get a soup and -- to keep us going and so on, and I had a very good man that I worked for, that he was the boss of the group of about, I don't know, 20 or so.
# Similarity: 0.74834764
#
# Text: A: In there, nothing.  Just...there was nothing to do.  Just... I mean, you went out...we went out to work every day.
# Similarity: 0.7481925
#
# Text: We couldn't own any stores.  I'm sure there was a catch for us.  The amount of food we could get was limited.
# Similarity: 0.74818164
#
# Text: Did we eat - it wasn't a dining room - but in a big room or whether we eat in our barracks?  You know, I couldn't remember.  I was trying to think, "How did we eat?"
# Similarity: 0.7474787
#
# Text: A: {Nothing, nothing.  They just ran out of the house}.  Just ran out, we didn't have anything. {
# Similarity: 0.7467482
#
# Text: A: Inside and + got no water.  It wasn't warm.  In the winter we had somenot a cooking facility but something was made to warm with.
# Similarity: 0.74594533
#
# Text: A: We stayed in the house, that's all.  We couldn't go anyplace so we stayed in.
# Similarity: 0.7450371
#
# Text: there was no television.  We did not have the radio in our house.  I recall we had like a three room apartment.
# Similarity: 0.7449187
#
# Text: A: When we were living in England we were not living together, no.  I lived in Kent, near Worcester Polytechnic.
# Similarity: 0.74424624
#
# Text: There's no... We had a little bed with a mattress.  This is very unusual and, uh, the only thing was no was no food.  So that money that I have, a couple of hundred zlotys, this lasts me for awhile to buy myself, and over there where we used to go to work, I used to take coal.
# Similarity: 0.7442299
#
# Text: A: No, we didn't keep ko-kosher at home, no.
# Similarity: 0.7442023
#
# Text: A: No school.
# Similarity: 0.74365866
#
# Text: We did not go to restaurants to eat.  We cooked.  And I was a very clean housekeeper so there was a lot of work at home.
# Similarity: 0.74355465
#
# Text: We had no homes to go.  Our homes were destroyed.  There were no Jews.
# Similarity: 0.7434946
#
# Text: A: Because we had a house for ourselves.  We never lived by ourselves, always my parents or his parents.  And we were independent there.
# Similarity: 0.74323
#
# Text: A: It was not a -- it was not taught in school.
# Similarity: 0.742742
#
# An error occurred: Driver timeout: (QueryConsistencyException/ReadTimeoutException) Cassandra timeout during read query at consistency LOCAL_ONE (1 responses were required but only 0 replica responded). In case this was generated during read repair, the consistency level is not representative of the actual consistency.. Server error '504 Gateway Timeout' for url 'https://2534174f-90b3-4e11-afb5-8ee29c3c090d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/HolocaustTestimonies'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/504
