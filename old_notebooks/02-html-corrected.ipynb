# %% [markdown]
# # Introduction
#
# This is the first of a series of notebooks that will guide you through processing oral interview PDFs from the United States Holocaust Memorial Museum. These notebooks, along with several datasets and machine learning models, are an output of the NEH-funded Placing the Holocaust Project. A collection of these PDFs, which are in English exclusively, are available on HuggingFace [here](https://huggingface.co/datasets/placingholocaust/ushmm-pdfs).
#
# ## Objective of Notebook
#
# This notebook will:
#
# - Walk through correcting the OCR
# - Demonstrate how to use the `ushmm` Python package for processing the PDFs.
#
# This will be the most computationally expensive portion of the workflow.
#
# # Getting Started
#
# In order to work with this notebook, you will need to have several packages already installed. To install these packages, you can use the `requirements.txt` file. Or, you can install these with the following pip command inside this notebook:

# %%
import os
os.chdir('..')

import glob
import datasets
import pandas as pd
from src.visualize import visualize_diff
from src.clean import clean_html

# %%
metadata = datasets.load_dataset("placingholocaust/testimony-metadata")["train"]
metadata
# Out:
# Dataset({
#     features: ['RG Number', 'PDF URL', 'USHMM URL', 'First Name', 'Middle Name', 'Last Name', 'Birth Name', 'Gender', 'Birth Date', 'Birth Year', 'Place of Birth', 'Country', 'Experience Group', 'Ghetto(s) Encyclopedia', 'Ghetto', 'Camp(s) Encyclopedia', 'Camp', 'Non-SS Camp  ', 'Region', 'Needs Research', 'Data Entry', 'Accession', 'Notes:', 'Revisit'],
#     num_rows: 977
# })

# %%
df = pd.DataFrame(metadata)
df
# Out:
#              RG Number                                            PDF URL  \
# 0    RG-50.549.02.0033  https://collections.ushmm.org/oh_findingaids/R...
# 1    RG-50.549.02.0072  https://collections.ushmm.org/oh_findingaids/R...
# 2    RG-50.549.02.0035  https://collections.ushmm.org/oh_findingaids/R...
# 3       RG-50.471.0015  https://collections.ushmm.org/oh_findingaids/R...
# 4       RG-50.030.0585  https://collections.ushmm.org/oh_findingaids/R...
# ..                 ...                                                ...
# 972  RG-50.549.02.0073  https://collections.ushmm.org/oh_findingaids/R...
# 973     RG-50.030.0137  https://collections.ushmm.org/oh_findingaids/R...
# 974     RG-50.030.0058  https://collections.ushmm.org/oh_findingaids/R...
# 975  RG-50.549.02.0078  https://collections.ushmm.org/oh_findingaids/R...
# 976  RG-50.549.02.0038  https://collections.ushmm.org/oh_findingaids/R...
#
#                                              USHMM URL First Name  \
# 0    https://collections.ushmm.org/search/catalog/i...      Hetty
# 1    https://collections.ushmm.org/search/catalog/i...    Emanuel
# 2    https://collections.ushmm.org/search/catalog/i...     Judith
# 3    https://collections.ushmm.org/search/catalog/i...     Esther
# 4    https://collections.ushmm.org/search/catalog/i...     Eugene
# ..                                                 ...        ...
# 972  https://collections.ushmm.org/search/catalog/i...      Flory
# 973  https://collections.ushmm.org/search/catalog/i...  Cornelius
# 974  https://collections.ushmm.org/search/catalog/i...      Isaac
# 975  https://collections.ushmm.org/search/catalog/i...      Lucie
# 976  https://collections.ushmm.org/search/catalog/i...      Isaac
#
#      Middle Name  Last Name      Birth Name Gender  Birth Date  Birth Year  \
# 0    d'Ancona de     Leeuwe  Hetty D'Ancona      F  1930-05-01      1930.0
# 1           None     Mandel            None      M        None      1936.0
# 2           None     Meisel            None      F        None      1929.0
# 3           None      Lurie            None      F        None         NaN
# 4           None     Miller            None      M  1923-10-16      1923.0
# ..           ...        ...             ...    ...         ...         ...
# 972         None     Jagoda            None      F  1923-12-21      1923.0
# 973         None       Loen            None      M  1922-05-02      1922.0
# 974         None      Danon            None      M        None      1929.0
# 975         None  Rosenberg            None      F        None      1921.0
# 976         None      Danon            None      M  1929-06-24      1929.0
#
#      ...  Ghetto Camp(s) Encyclopedia  Camp Non-SS Camp   Region  \
# 0    ...    None                 None  None          None   None
# 1    ...    None                 None  None          None   None
# 2    ...  Kaunas                 None  None          None   None
# 3    ...    None                 None  None          None   None
# 4    ...    Lodz     Auschwitz,Dachau  None          None   None
# ..   ...     ...                  ...   ...           ...    ...
# 972  ...    None                 None  None          None   None
# 973  ...    None                 None  None          None   None
# 974  ...    None                 None  None          None   None
# 975  ...    None                 None  None          None   None
# 976  ...    None                 None  None          None   None
#
#     Needs Research Data Entry       Accession  \
# 0             None         CL     1999.A.0293
# 1          checked         GG        2003.205
# 2          checked         GG     1999.A.0024
# 3             None         CL  1998.A.0119.15
# 4          checked         GG        2010.249
# ..             ...        ...             ...
# 972           None         GG         2004.48
# 973           None         CL      1990.437.1
# 974           None         GG            None
# 975        checked         CL        2004.214
# 976           None         CL     1999.A.0038
#
#                                                 Notes:  Revisit
# 0                                                 None     None
# 1                                  Follow-up interview     None
# 2    This is a follow-up interview to one already d...  checked
# 3                                                 None     None
# 4                                                 None     None
# ..                                                 ...      ...
# 972                                          Follow-up  checked
# 973                                               None     None
# 974                                               None     None
# 975       Not a survivor, volunteered for the museum?      None
# 976                                               None     None
#
# [977 rows x 24 columns]

# %%
html_files = glob.glob("./data/pdfs/*.html")
print(html_files[:5])
print(len(html_files))
# Out:
# ['./data/pdfs/RG-50.030.0706_tcn_en.html', './data/pdfs/RG-50.030.0670_sum_en.html', './data/pdfs/RG-50.030.0414_trs_en.html', './data/pdfs/RG-50.030.0144_trs_en.html', './data/pdfs/RG-50.549.02.0062_trs_en.html']
# 1214

# %%
approved_files = []
for filename in html_files:
    if "sum" not in filename and "trs_en" in filename:
        approved_files.append(filename)
len(approved_files)
# Out:
# 949

# %%
approved_files.sort()

# %%
for filename in approved_files:
    clean_html(filename, "./data/cleaned_htmls")
# Out:
# No removals made in ./data/pdfs/RG-50.030.0001_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0001_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0002_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0002_trs_en_cleaned.html
#
# Removals for ./data/pdfs/RG-50.030.0003_trs_en.html:
# Removed 'http://collections.ushmm.org Contact reference@ushmm.org for further information about this collection' 34 time(s)
# Removed 'This is a verbatim transcript of spoken word. It is not the primary source, and it has not been checked for spelling or accuracy.' 34 time(s)
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0003_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0004_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0004_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0006_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0006_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0007_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0007_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0008_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0008_trs_en_cleaned.html
#
# Removals for ./data/pdfs/RG-50.030.0011_trs_en.html:
# Removed 'http://collections.ushmm.org Contact reference@ushmm.org for further information about this collection' 9 time(s)
# Removed 'This is a verbatim transcript of spoken word. It is not the primary source, and it has not been checked for spelling or accuracy.' 9 time(s)
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0011_trs_en_cleaned.html
#
# Removals for ./data/pdfs/RG-50.030.0012_trs_en.html:
# Removed 'http://collections.ushmm.org Contact reference@ushmm.org for further information about this collection' 24 time(s)
# Removed 'This is a verbatim transcript of spoken word. It is not the primary source, and it has not been checked for spelling or accuracy.' 24 time(s)
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0012_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0013_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0013_trs_en_cleaned.html
#
# Removals for ./data/pdfs/RG-50.030.0014_trs_en.html:
# Removed 'http://collections.ushmm.org Contact reference@ushmm.org for further information about this collection' 11 time(s)
# Removed 'This is a verbatim transcript of spoken word. It is not the primary source, and it has not been checked for spelling or accuracy.' 11 time(s)
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0014_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0016_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0016_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0017_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0017_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0018_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0018_trs_en_cleaned.html
#
# Removals for ./data/pdfs/RG-50.030.0021_trs_en.html:
# Removed 'http://collections.ushmm.org Contact reference@ushmm.org for further information about this collection' 24 time(s)
# Removed 'This is a verbatim transcript of spoken word. It is not the primary source, and it has not been checked for spelling or accuracy.' 24 time(s)
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0021_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0022_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0022_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0023_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0023_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0025_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0025_trs_en_cleaned.html
#
# Removals for ./data/pdfs/RG-50.030.0026_trs_en.html:
# Removed 'http://collections.ushmm.org Contact reference@ushmm.org for further information about this collection' 45 time(s)
# Removed 'This is a verbatim transcript of spoken word. It is not the primary source, and it has not been checked for spelling or accuracy.' 45 time(s)
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0026_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0027_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0027_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0028_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0028_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0029_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0029_trs_en_cleaned.html
#
# Removals for ./data/pdfs/RG-50.030.0030_trs_en.html:
# Removed 'http://collections.ushmm.org Contact reference@ushmm.org for further information about this collection' 46 time(s)
# Removed 'This is a verbatim transcript of spoken word. It is not the primary source, and it has not been checked for spelling or accuracy.' 46 time(s)
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0030_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0033_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0033_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0035_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0035_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0036_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0036_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0038_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0038_trs_en_cleaned.html
#
# Removals for ./data/pdfs/RG-50.030.0040_trs_en.html:
# Removed 'http://collections.ushmm.org Contact reference@ushmm.org for further information about this collection' 23 time(s)
# Removed 'This is a verbatim transcript of spoken word. It is not the primary source, and it has not been checked for spelling or accuracy.' 23 time(s)
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0040_trs_en_cleaned.html
#
# No removals made in ./data/pdfs/RG-50.030.0041_trs_en.html
# Cleaned HTML saved to: ./data/cleaned_htmls/RG-50.030.0041_trs_en_cleaned.html
#
# Removals for ./data/pdfs/RG-50.030.0042_trs_en.html:
# Removed 'http://collections.ushmm.org Contact reference@ushmm.org for further information about this collection'